# %% [markdown]
# # Gathering data by Web Scraping .
# This is data of Internshala's Remote Internships .

# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
webpage = requests.get("https://internshala.com/internships/work-from-home-internships/page=1/" , headers= headers).text

# %%
soup = BeautifulSoup(webpage , 'lxml')

# %%
# print(soup.prettify())

# %%
soup.find_all('p' , class_ = 'company-name')[0].text
# Out:
# '\n                            APOGEE, BITS Pilani                        '

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# OR
# OR
# As per my preferences
# Profile
# Location
# Work From Home
# Part Time
# Stipend
# Salary
# Experience
# All Filters
# APOGEE, BITS Pilani
# Treta Yug Foundation
# HyperProspect
# HyperProspect
# Emvoke Technologies Private Limited
# Thedatataskers
# Tare Zameen Foundation
# Hamari Pahchan NGO
# LearnAsYouGo Private Limited
# CipherSchools
# Get FREE Internship and Job Preparation training
# Gain a competitive edge with Internshala
# 4-8 weeks
# Placement Assistance
# Join
# and build your dream career
# Integral Solution
# Integral Solution
# Teqlawn
# University Insights
# SkillGenic Academy
# Bezt Labs
# University Insights
# Kads Consultancy
# SkillGenic Academy
# Mierae Solar Energy Private Limited
# University Insights
# University Insights
# KUNDUZ TECHNOLOGIES PRIVATE LIMITED
# Equiprime Capital
# University Insights
# Better
# Group Futurista
# Search My Career
# Quora Media
# Fazil Baker
# The Affordable Organic Store
# University Insights
# Inspacco
# ...

# %%
soup.find_all('span', class_ = 'stipend' )[0].text
# Out:
# 'Performance Based'

# %%
for i in soup.find_all('span', class_ = 'stipend'):
    print(i.text.strip())
# Out:
# Performance Based
# ₹ 1,000 /month +  Incentives
# ₹ 6,000 /month +  Incentives
# ₹ 6,000 /month +  Incentives
# ₹ 7,000 /month +  Incentives
# ₹ 8,000-12,000 /month
# ₹ 1,000 /month +  Incentives
# 10% of Funds Raised
# ₹ 25,000-30,000 /month
# ₹ 15,000-30,000 /month
# ₹ 5,000 /month
# ₹ 7,500 /month
# ₹ 3,000-5,000 /month
# ₹ 1,500-2,500 /month
# ₹ 1,000-3,000 /month
# ₹ 7,500 /month
# ₹ 1,500-2,500 /month
# ₹ 2,000 /month
# ₹ 1,000-3,000 /month
# ₹ 3,000 /month
# ₹ 1,500-2,500 /month
# ₹ 1,500-2,500 /month
# ₹ 5,000-6,000 /month
# ₹ 3,000-7,000 /month
# ₹ 1,500-2,500 /month
# ₹ 10,000 /month
# ₹ 6,000 /month
# ₹ 2,500-3,000 /month
# ₹ 2,000 /month
# ₹ 5,000-7,500 /month
# ₹ 1,500 /month
# ₹ 1,500-2,500 /month
# ₹ 8,000-15,000 /month
# ₹ 5,000-6,000 /month
# ₹ 15,000-20,000 /month
# ₹ 5,000-9,000 /month
# ₹ 5,000-9,000 /month
# ₹ 5,000 /month +  Incentives
# ₹ 5,000-9,000 /month
# ₹ 1,000 /month
# ₹ 5,000-9,000 /month
# ₹ 8,000-15,000 /month
# ₹ 15,000-30,000 /month
# ...

# %%
durations = [] 
for span in soup.find_all('span'):
    if 'Months' in span.text: durations.append(span.text)

for duration in durations:
     print(duration)
# Out:
# 2 Months
# 2 Months
# 2 Months
# 6 Months
# 3 Months
# 4 Months
# 3 Months
# 3 Months
# 3 Months
# 6 Months
# 6 Months
# 2 Months
# 4 Months
# 4 Months
# 3 Months
# 3 Months
# 6 Months
# 6 Months
# 6 Months
# 3 Months
# 3 Months
# 6 Months
# 6 Months
# 3 Months
# 3 Months
# 6 Months
# 6 Months
# 6 Months
# 3 Months
# 6 Months
# 3 Months
# 2 Months
# 6 Months
# 4 Months

# %%
company = soup.find_all('div' , class_ = "internship_meta duration_meta")

# %%
name =[]
stipend = []
# duration = [] 
position =[]
for i in company:
    name.append(i.find('p' , class_ = 'company-name').text.strip())
    stipend.append(i.find('span', class_ = 'stipend').text.strip())
    # durations.append(i.find('div', class_="row-1-item").text.strip())
    position.append(i.find('a', class_ = 'job-title-href').text.strip())

# for span in soup.find_all('span'):
#      if 'Months' in span.text or 'Years' in span.text:
#          duration.append(span.text)
        
d ={'name':name , 'stipend':stipend , 'Job title': position} 
df = pd.DataFrame(d)
df
# Out:
#                                          name                       stipend  \
# 0                         APOGEE, BITS Pilani             Performance Based
# 1                        Treta Yug Foundation  ₹ 1,000 /month +  Incentives
# 2                               HyperProspect  ₹ 6,000 /month +  Incentives
# 3                               HyperProspect  ₹ 6,000 /month +  Incentives
# 4         Emvoke Technologies Private Limited  ₹ 7,000 /month +  Incentives
# 5                              Thedatataskers         ₹ 8,000-12,000 /month
# 6                      Tare Zameen Foundation  ₹ 1,000 /month +  Incentives
# 7                          Hamari Pahchan NGO           10% of Funds Raised
# 8                LearnAsYouGo Private Limited        ₹ 25,000-30,000 /month
# 9                               CipherSchools        ₹ 15,000-30,000 /month
# 10                          Integral Solution                ₹ 5,000 /month
# ...

# %%
df.shape
# Out:
# (48, 3)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

final_data = pd.DataFrame()
for j in range(1, 85):
    url = f"https://internshala.com/internships/work-from-home-internships/page-{j}"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'
    }
    webpage = requests.get(url, headers=headers).text

    soup = BeautifulSoup(webpage, 'lxml')

    companies = soup.find_all('div', class_='internship_meta duration_meta')
    name = []
    stipend = []
    position = []
    for company in companies:
        name.append(company.find('p', class_='company-name').text.strip())
        stipend.append(company.find('span', class_='stipend').text.strip())
        position.append(company.find('a', class_='job-title-href').text.strip())

    d = {'name': name, 'stipend': stipend, 'Job title': position}
    df = pd.DataFrame(d)

    final_data = pd.concat([final_data, df], ignore_index=True)

print(final_data)
# Out:
#                                      name                       stipend  \
# 0                     APOGEE, BITS Pilani             Performance Based
# 1                    Treta Yug Foundation  ₹ 1,000 /month +  Incentives
# 2                           HyperProspect  ₹ 6,000 /month +  Incentives
# 3                           HyperProspect  ₹ 6,000 /month +  Incentives
# 4     Emvoke Technologies Private Limited  ₹ 7,000 /month +  Incentives
# ...                                   ...                           ...
# 3363                          Nicola Tech         ₹ 5,000-10,000 /month
# 3364  SPACE For Early Childhood Education                        Unpaid
# 3365  SPACE For Early Childhood Education                        Unpaid
# 3366  SPACE For Early Childhood Education                        Unpaid
# 3367  SPACE For Early Childhood Education                        Unpaid
#
#                           Job title
# 0                 Campus Ambassador
# ...

# %%
df_1 = pd.DataFrame(final_data)
df_1
# Out:
#                                      name                       stipend  \
# 0                     APOGEE, BITS Pilani             Performance Based
# 1                    Treta Yug Foundation  ₹ 1,000 /month +  Incentives
# 2                           HyperProspect  ₹ 6,000 /month +  Incentives
# 3                           HyperProspect  ₹ 6,000 /month +  Incentives
# 4     Emvoke Technologies Private Limited  ₹ 7,000 /month +  Incentives
# ...                                   ...                           ...
# 3363                          Nicola Tech         ₹ 5,000-10,000 /month
# 3364  SPACE For Early Childhood Education                        Unpaid
# 3365  SPACE For Early Childhood Education                        Unpaid
# 3366  SPACE For Early Childhood Education                        Unpaid
# 3367  SPACE For Early Childhood Education                        Unpaid
#
#                           Job title
# 0                 Campus Ambassador
# ...

# %%
#without any duplicate values 
df_1.drop_duplicates(inplace=True)
df_1
# Out:
#                                      name                       stipend  \
# 0                     APOGEE, BITS Pilani             Performance Based
# 1                    Treta Yug Foundation  ₹ 1,000 /month +  Incentives
# 2                           HyperProspect  ₹ 6,000 /month +  Incentives
# 3                           HyperProspect  ₹ 6,000 /month +  Incentives
# 4     Emvoke Technologies Private Limited  ₹ 7,000 /month +  Incentives
# ...                                   ...                           ...
# 3363                          Nicola Tech         ₹ 5,000-10,000 /month
# 3364  SPACE For Early Childhood Education                        Unpaid
# 3365  SPACE For Early Childhood Education                        Unpaid
# 3366  SPACE For Early Childhood Education                        Unpaid
# 3367  SPACE For Early Childhood Education                        Unpaid
#
#                           Job title
# 0                 Campus Ambassador
# ...

# %%
df_1.shape
# Out:
# (3319, 3)
